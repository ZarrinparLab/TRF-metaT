# %% [markdown]
# # Birdman TRF plotting

# %%
import pandas as pd
import qiime2 as q2
import numpy as np
import biom

# plotting 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def read_results(p):
    return pd.read_csv(p, sep='\t', index_col='Feature')
def unpack_hdi_and_filter(df, col):
    df[['lower', 'upper']] = df[col].str.split(',', expand=True)
    # remove ( from lower and ) from upper and convert to float 
    df.lower = df.lower.str[1:].astype('float')
    df.upper = df.upper.str[:-1].astype('float')
    
    df['credible'] = np.where((df.lower > 0) | (df.upper < 0), 'yes', 'no')
    
    df.upper = df.upper - df[col.replace('hdi', 'mean')]
    df.lower = df[col.replace('hdi', 'mean')] - df.lower
    
    return df

# %% [markdown]
# ## FA vs. FT

# %%
light=pd.read_csv('/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences/inferences-results/species_pfam_BSHonly_clean_rmzero_noNT_light.beta_var.tsv', sep='\t', index_col='Feature')
light
# Out:
#                                  Intercept_mean  \
# Feature
# UBA3282_sp003611805                   -7.332932
# Paraferrimonas_sedimenticola          -7.167943
# Coprobacter_fastidiosus               -7.366536
# Lactiplantibacillus_plantarum_A       -7.167943
# Methanomethylophilus_alvus            -7.550946
# ...                                         ...
# Enterococcus_A_avium                  -8.499272
# Adlercreutzia_mucosicola              -7.366536
# Enterousia_sp902776515                -5.213224
# 1XD42-69_sp003612565                  -8.540691
# 14-2_sp000403315                      -7.460928
#
#                                  C(condition, Treatment('FA'))[T.FT]_mean  \
# Feature
# UBA3282_sp003611805                                              2.830894
# Paraferrimonas_sedimenticola                                    -1.580178
# Coprobacter_fastidiosus                                         -1.163066
# Lactiplantibacillus_plantarum_A                                 -1.580178
# Methanomethylophilus_alvus                                      -1.727289
# ...                                                                   ...
# Enterococcus_A_avium                                             4.555740
# Adlercreutzia_mucosicola                                        -1.163066
# Enterousia_sp902776515                                          -2.705757
# 1XD42-69_sp003612565                                            -2.862167
# 14-2_sp000403315                                                 2.090496
#
#                                  C(condition, Treatment('FA'))[T.NA]_mean  \
# Feature
# UBA3282_sp003611805                                              4.373506
# Paraferrimonas_sedimenticola                                     1.284314
# Coprobacter_fastidiosus                                          0.972192
# Lactiplantibacillus_plantarum_A                                  1.284314
# Methanomethylophilus_alvus                                       0.971577
# ...                                                                   ...
# Enterococcus_A_avium                                            -3.738032
# Adlercreutzia_mucosicola                                         0.972192
# Enterousia_sp902776515                                          -3.965071
# 1XD42-69_sp003612565                                             5.848858
# 14-2_sp000403315                                                 5.692908
#
#                                  Intercept_std  \
# Feature
# UBA3282_sp003611805                   1.768088
# Paraferrimonas_sedimenticola          4.030532
# Coprobacter_fastidiosus               3.553826
# Lactiplantibacillus_plantarum_A       4.030532
# Methanomethylophilus_alvus            3.576916
# ...                                        ...
# Enterococcus_A_avium                  2.712726
# Adlercreutzia_mucosicola              3.553826
# Enterousia_sp902776515                2.542292
# 1XD42-69_sp003612565                  1.863845
# 14-2_sp000403315                      1.701537
#
#                                  C(condition, Treatment('FA'))[T.FT]_std  \
# Feature
# UBA3282_sp003611805                                             1.862949
# Paraferrimonas_sedimenticola                                    4.489458
# Coprobacter_fastidiosus                                         4.372734
# Lactiplantibacillus_plantarum_A                                 4.489458
# Methanomethylophilus_alvus                                      4.343740
# ...                                                                  ...
# Enterococcus_A_avium                                            2.701615
# Adlercreutzia_mucosicola                                        4.372734
# Enterousia_sp902776515                                          4.167764
# 1XD42-69_sp003612565                                            3.744614
# 14-2_sp000403315                                                1.919310
#
#                                  C(condition, Treatment('FA'))[T.NA]_std  \
# Feature
# UBA3282_sp003611805                                             1.845429
# Paraferrimonas_sedimenticola                                    3.449272
# Coprobacter_fastidiosus                                         3.269518
# Lactiplantibacillus_plantarum_A                                 3.449272
# Methanomethylophilus_alvus                                      3.292424
# ...                                                                  ...
# Enterococcus_A_avium                                            3.646533
# Adlercreutzia_mucosicola                                        3.269518
# Enterousia_sp902776515                                          4.089022
# 1XD42-69_sp003612565                                            1.880652
# 14-2_sp000403315                                                1.748148
#
#                                         Intercept_hdi  \
# Feature
# UBA3282_sp003611805              (-10.7141, -4.33964)
# Paraferrimonas_sedimenticola      (-14.1069, 1.01744)
# Coprobacter_fastidiosus          (-14.011, -0.198514)
# Lactiplantibacillus_plantarum_A   (-14.1069, 1.01744)
# Methanomethylophilus_alvus       (-14.6262, -0.95767)
# ...                                               ...
# Enterococcus_A_avium              (-13.7188, -3.8916)
# Adlercreutzia_mucosicola         (-14.011, -0.198514)
# Enterousia_sp902776515           (-9.20609, 0.291006)
# 1XD42-69_sp003612565             (-12.2397, -5.42029)
# 14-2_sp000403315                  (-10.6177, -4.3064)
#
#                                 C(condition, Treatment('FA'))[T.FT]_hdi  \
# Feature
# UBA3282_sp003611805                                (-0.566508, 6.37013)
# Paraferrimonas_sedimenticola                        (-10.1383, 6.51841)
# Coprobacter_fastidiosus                              (-9.77565, 6.9612)
# Lactiplantibacillus_plantarum_A                     (-10.1383, 6.51841)
# Methanomethylophilus_alvus                          (-10.7205, 5.56087)
# ...                                                                 ...
# Enterococcus_A_avium                                (-0.524577, 9.8555)
# Adlercreutzia_mucosicola                             (-9.77565, 6.9612)
# Enterousia_sp902776515                              (-10.5861, 5.19939)
# 1XD42-69_sp003612565                                (-10.0237, 3.44508)
# 14-2_sp000403315                                    (-1.17455, 5.93199)
#
#                                 C(condition, Treatment('FA'))[T.NA]_hdi
# Feature
# UBA3282_sp003611805                                  (1.26212, 8.06375)
# Paraferrimonas_sedimenticola                        (-4.83729, 8.44004)
# Coprobacter_fastidiosus                             (-5.26001, 7.31713)
# Lactiplantibacillus_plantarum_A                     (-4.83729, 8.44004)
# Methanomethylophilus_alvus                          (-5.15192, 7.47457)
# ...                                                                 ...
# Enterococcus_A_avium                                 (-10.5141, 3.0135)
# Adlercreutzia_mucosicola                            (-5.26001, 7.31713)
# Enterousia_sp902776515                              (-12.5533, 3.34337)
# 1XD42-69_sp003612565                                 (2.62788, 9.55955)
# 14-2_sp000403315                                      (2.5428, 9.11256)
#
# [67 rows x 9 columns]

# %%
data_dict = {
    'BSH_light': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences/inferences-results/species_pfam_BSHonly_clean_rmzero_noNT_light.beta_var.tsv', 
    'BSH_dark': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences/inferences-results/species_pfam_BSHonly_clean_rmzero_noNT_dark.beta_var.tsv', 
}

vars_to_check = {
    'BSH_light' : 'C(condition, Treatment(\'FA\'))[T.FT]_',
    'BSH_dark' : 'C(condition, Treatment(\'FA\'))[T.FT]_'
}

# %%
# update names 
for k in data_dict.keys():
    df = read_results(data_dict[k])
    for v in vars_to_check: 
        if v in k: 
            var = vars_to_check[v] 
    print(k)
    print('Unfiltered Shape:  ' + str(df.shape))
    sub_df = unpack_hdi_and_filter(df, var+'hdi')
    print('Filtered Shape: ' + str(sub_df.loc[sub_df['credible'] == 'yes'].shape))
    sub_df.rename_axis(index='Feature', inplace=True)
    
    data_dict[k] = sub_df.sort_values(by=var+'mean')
# Out:
# BSH_light
# Unfiltered Shape:  (67, 9)
# Filtered Shape: (1, 12)
# BSH_dark
# Unfiltered Shape:  (67, 9)
# Filtered Shape: (4, 12)

# %%
data_dict
# Out:
# {'BSH_light':                                 Intercept_mean  \
#  Feature
#  Acetatifactor_muris                  -3.812868
#  Anaerotruncus_sp000403395            -5.032052
#  Butyribacter_sp003612285             -4.716272
#  Acinetobacter_tandoii                -6.208566
#  Evtepia_gabavorous                   -5.095846
#  ...                                        ...
#  Acidithiobacillus_ferrooxidans       -7.289938
#  Enterousia_intestinigallinarum       -7.289938
#  Choladousia_sp003612585              -5.361327
#  Enterococcus_B_faecium               -8.914363
#  Enterococcus_A_avium                 -8.499272
#
#                                  C(condition, Treatment('FA'))[T.FT]_mean  \
#  Feature
#  Acetatifactor_muris                                            -4.867996
#  Anaerotruncus_sp000403395                                      -4.317853
#  Butyribacter_sp003612285                                       -3.686674
#  Acinetobacter_tandoii                                          -3.453549
#  Evtepia_gabavorous                                             -3.319004
#  ...                                                                  ...
#  Acidithiobacillus_ferrooxidans                                  2.982327
#  Enterousia_intestinigallinarum                                  2.982327
#  Choladousia_sp003612585                                         3.066793
#  Enterococcus_B_faecium                                          4.429770
#  Enterococcus_A_avium                                            4.555740
#
#                                  C(condition, Treatment('FA'))[T.NA]_mean  \
#  Feature
#  Acetatifactor_muris                                            -1.327207
#  Anaerotruncus_sp000403395                                      -0.868767
#  Butyribacter_sp003612285                                        0.035648
#  Acinetobacter_tandoii                                          -5.171108
#  Evtepia_gabavorous                                             -4.590542
#  ...                                                                  ...
#  Acidithiobacillus_ferrooxidans                                 -2.927196
#  Enterousia_intestinigallinarum                                 -2.927196
#  Choladousia_sp003612585                                        -2.116149
#  Enterococcus_B_faecium                                         -3.759299
#  Enterococcus_A_avium                                           -3.738032
#
#                                  Intercept_std  \
#  Feature
#  Acetatifactor_muris                  1.223780
#  Anaerotruncus_sp000403395            1.247336
#  Butyribacter_sp003612285             1.673998
#  Acinetobacter_tandoii                1.351199
#  Evtepia_gabavorous                   2.080810
#  ...                                       ...
#  Acidithiobacillus_ferrooxidans       3.749290
#  Enterousia_intestinigallinarum       3.749290
#  Choladousia_sp003612585              4.074135
#  Enterococcus_B_faecium               2.357910
#  Enterococcus_A_avium                 2.712726
#
#                                  C(condition, Treatment('FA'))[T.FT]_std  \
#  Feature
#  Acetatifactor_muris                                            3.305939
#  Anaerotruncus_sp000403395                                      3.296117
#  Butyribacter_sp003612285                                       3.848202
#  Acinetobacter_tandoii                                          3.545211
#  Evtepia_gabavorous                                             3.980656
#  ...                                                                 ...
#  Acidithiobacillus_ferrooxidans                                 3.560964
#  Enterousia_intestinigallinarum                                 3.560964
#  Choladousia_sp003612585                                        3.903624
#  Enterococcus_B_faecium                                         2.394846
#  Enterococcus_A_avium                                           2.701615
#
#                                  C(condition, Treatment('FA'))[T.NA]_std  \
#  Feature
#  Acetatifactor_muris                                            1.624133
#  Anaerotruncus_sp000403395                                      1.475727
#  Butyribacter_sp003612285                                       2.129525
#  Acinetobacter_tandoii                                          3.622310
#  Evtepia_gabavorous                                             4.051204
#  ...                                                                 ...
#  Acidithiobacillus_ferrooxidans                                 4.214186
#  Enterousia_intestinigallinarum                                 4.214186
#  Choladousia_sp003612585                                        4.967629
#  Enterococcus_B_faecium                                         3.513328
#  Enterococcus_A_avium                                           3.646533
#
#                                          Intercept_hdi  \
#  Feature
#  Acetatifactor_muris              (-5.85596, -1.53672)
#  Anaerotruncus_sp000403395        (-7.24991, -2.47798)
#  Butyribacter_sp003612285         (-7.69646, -1.31069)
#  Acinetobacter_tandoii             (-8.88649, -3.8567)
#  Evtepia_gabavorous               (-9.07245, -1.23208)
#  ...                                               ...
#  Acidithiobacillus_ferrooxidans  (-14.2761, 0.0772695)
#  Enterousia_intestinigallinarum  (-14.2761, 0.0772695)
#  Choladousia_sp003612585           (-12.8981, 2.37397)
#  Enterococcus_B_faecium           (-13.4853, -4.53101)
#  Enterococcus_A_avium              (-13.7188, -3.8916)
#
#                                 C(condition, Treatment('FA'))[T.FT]_hdi  \
#  Feature
#  Acetatifactor_muris                                (-11.6391, 1.07651)
#  Anaerotruncus_sp000403395                          (-11.4136, 1.12643)
#  Butyribacter_sp003612285                           (-10.8752, 3.77405)
#  Acinetobacter_tandoii                                (-10.3665, 3.009)
#  Evtepia_gabavorous                                 (-11.5795, 4.14247)
#  ...                                                                ...
#  Acidithiobacillus_ferrooxidans                       (-4.37654, 9.499)
#  Enterousia_intestinigallinarum                       (-4.37654, 9.499)
#  Choladousia_sp003612585                             (-4.1118, 10.4818)
#  Enterococcus_B_faecium                            (0.0483871, 9.07958)
#  Enterococcus_A_avium                               (-0.524577, 9.8555)
#
#                                 C(condition, Treatment('FA'))[T.NA]_hdi  \
#  Feature
#  Acetatifactor_muris                                (-4.58401, 1.58394)
#  Anaerotruncus_sp000403395                          (-3.67719, 1.67568)
#  Butyribacter_sp003612285                           (-3.74464, 4.35739)
#  Acinetobacter_tandoii                              (-12.5331, 1.43667)
#  Evtepia_gabavorous                                 (-11.7849, 4.67233)
#  ...                                                                ...
#  Acidithiobacillus_ferrooxidans                     (-9.93217, 5.35492)
#  Enterousia_intestinigallinarum                     (-9.93217, 5.35492)
#  Choladousia_sp003612585                            (-10.9739, 7.46553)
#  Enterococcus_B_faecium                             (-10.4682, 2.79327)
#  Enterococcus_A_avium                                (-10.5141, 3.0135)
#
#                                     lower     upper credible
#  Feature
#  Acetatifactor_muris             6.771104  5.944506       no
#  Anaerotruncus_sp000403395       7.095747  5.444283       no
#  Butyribacter_sp003612285        7.188526  7.460724       no
#  Acinetobacter_tandoii           6.912951  6.462549       no
#  Evtepia_gabavorous              8.260496  7.461474       no
#  ...                                  ...       ...      ...
#  Acidithiobacillus_ferrooxidans  7.358867  6.516673       no
#  Enterousia_intestinigallinarum  7.358867  6.516673       no
#  Choladousia_sp003612585         7.178593  7.415007       no
#  Enterococcus_B_faecium          4.381383  4.649810      yes
#  Enterococcus_A_avium            5.080317  5.299760       no
#
#  [67 rows x 12 columns],
#  'BSH_dark':                              Intercept_mean  \
#  Feature
#  Lactobacillus_gasseri             -4.429601
#  Paramuribaculum_intestinale       -2.408047
#  Limosilactobacillus_reuteri       -4.404889
#  Lactobacillus_hominis             -3.768135
#  Anaerotruncus_sp000403395         -5.235430
#  ...                                     ...
#  Adlercreutzia_caecimuris          -7.297105
#  Acutalibacter_sp009936055         -4.794075
#  Acutalibacter_muris               -7.322962
#  Kineothrix_sp000403275            -5.342999
#  14-2_sp000403315                  -7.436411
#
#                               C(condition, Treatment('FA'))[T.FT]_mean  \
#  Feature
#  Lactobacillus_gasseri                                       -4.852391
#  Paramuribaculum_intestinale                                 -4.511779
#  Limosilactobacillus_reuteri                                 -4.095088
#  Lactobacillus_hominis                                       -4.077930
#  Anaerotruncus_sp000403395                                   -3.663560
#  ...                                                               ...
#  Adlercreutzia_caecimuris                                     3.083161
#  Acutalibacter_sp009936055                                    3.087332
#  Acutalibacter_muris                                          3.129790
#  Kineothrix_sp000403275                                       3.246705
#  14-2_sp000403315                                             3.438222
#
#                               C(condition, Treatment('FA'))[T.NA]_mean  \
#  Feature
#  Lactobacillus_gasseri                                       -6.729301
#  Paramuribaculum_intestinale                                 -6.528109
#  Limosilactobacillus_reuteri                                 -5.755493
#  Lactobacillus_hominis                                       -1.501897
#  Anaerotruncus_sp000403395                                   -0.944320
#  ...                                                               ...
#  Adlercreutzia_caecimuris                                    -2.541650
#  Acutalibacter_sp009936055                                   -2.088087
#  Acutalibacter_muris                                         -2.842481
#  Kineothrix_sp000403275                                       0.028946
#  14-2_sp000403315                                             5.832455
#
#                               Intercept_std  \
#  Feature
#  Lactobacillus_gasseri             0.528382
#  Paramuribaculum_intestinale       1.177290
#  Limosilactobacillus_reuteri       1.437293
#  Lactobacillus_hominis             1.369046
#  Anaerotruncus_sp000403395         1.492132
#  ...                                    ...
#  Adlercreutzia_caecimuris          3.750115
#  Acutalibacter_sp009936055         4.114658
#  Acutalibacter_muris               3.505560
#  Kineothrix_sp000403275            1.029444
#  14-2_sp000403315                  1.561817
#
#                               C(condition, Treatment('FA'))[T.FT]_std  \
#  Feature
#  Lactobacillus_gasseri                                       2.899518
#  Paramuribaculum_intestinale                                 3.971758
#  Limosilactobacillus_reuteri                                 3.527361
#  Lactobacillus_hominis                                       3.705492
#  Anaerotruncus_sp000403395                                   3.525472
#  ...                                                              ...
#  Adlercreutzia_caecimuris                                    3.191772
#  Acutalibacter_sp009936055                                   3.730111
#  Acutalibacter_muris                                         3.276732
#  Kineothrix_sp000403275                                      1.273822
#  14-2_sp000403315                                            1.708168
#
#                               C(condition, Treatment('FA'))[T.NA]_std  \
#  Feature
#  Lactobacillus_gasseri                                       2.774776
#  Paramuribaculum_intestinale                                 3.676321
#  Limosilactobacillus_reuteri                                 3.610858
#  Lactobacillus_hominis                                       2.363141
#  Anaerotruncus_sp000403395                                   1.834539
#  ...                                                              ...
#  Adlercreutzia_caecimuris                                    4.248704
#  Acutalibacter_sp009936055                                   4.576615
#  Acutalibacter_muris                                         4.336015
#  Kineothrix_sp000403275                                      1.196741
#  14-2_sp000403315                                            1.604851
#
#                                        Intercept_hdi  \
#  Feature
#  Lactobacillus_gasseri          (-5.49851, -3.54503)
#  Paramuribaculum_intestinale   (-4.62307, -0.233899)
#  Limosilactobacillus_reuteri    (-6.89854, -1.72377)
#  Lactobacillus_hominis          (-6.1593, -0.969207)
#  Anaerotruncus_sp000403395      (-7.88461, -2.17555)
#  ...                                             ...
#  Adlercreutzia_caecimuris       (-13.5579, 0.451188)
#  Acutalibacter_sp009936055       (-11.7023, 3.72713)
#  Acutalibacter_muris          (-13.4649, -0.0987528)
#  Kineothrix_sp000403275         (-7.28367, -3.32566)
#  14-2_sp000403315                (-10.369, -4.54901)
#
#                              C(condition, Treatment('FA'))[T.FT]_hdi  \
#  Feature
#  Lactobacillus_gasseri                         (-10.3774, -0.076234)
#  Paramuribaculum_intestinale                     (-12.1309, 2.82914)
#  Limosilactobacillus_reuteri                     (-11.2547, 2.00087)
#  Lactobacillus_hominis                           (-11.4008, 2.71828)
#  Anaerotruncus_sp000403395                       (-10.8281, 2.52504)
#  ...                                                             ...
#  Adlercreutzia_caecimuris                         (-3.32033, 8.7399)
#  Acutalibacter_sp009936055                        (-4.04952, 10.209)
#  Acutalibacter_muris                             (-4.35739, 8.77795)
#  Kineothrix_sp000403275                          (0.786955, 5.60668)
#  14-2_sp000403315                                (0.572338, 7.02172)
#
#                              C(condition, Treatment('FA'))[T.NA]_hdi     lower  \
#  Feature
#  Lactobacillus_gasseri                          (-11.8629, -2.06293)  5.525009
#  Paramuribaculum_intestinale                     (-13.802, 0.319721)  7.619121
#  Limosilactobacillus_reuteri                    (-13.2885, 0.718027)  7.159612
#  Lactobacillus_hominis                            (-5.88799, 2.8901)  7.322870
#  Anaerotruncus_sp000403395                        (-4.54755, 2.4477)  7.164540
#  ...                                                             ...       ...
#  Adlercreutzia_caecimuris                        (-10.5674, 5.53845)  6.403491
#  Acutalibacter_sp009936055                       (-9.77449, 7.52966)  7.136852
#  Acutalibacter_muris                             (-10.9341, 5.66853)  7.487180
#  Kineothrix_sp000403275                           (-2.2094, 2.25495)  2.459750
#  14-2_sp000403315                                 (3.06165, 9.00512)  2.865884
#
#                                  upper credible
#  Feature
#  Lactobacillus_gasseri        4.776157      yes
#  Paramuribaculum_intestinale  7.340919       no
#  Limosilactobacillus_reuteri  6.095958       no
#  Lactobacillus_hominis        6.796210       no
#  Anaerotruncus_sp000403395    6.188600       no
#  ...                               ...      ...
#  Adlercreutzia_caecimuris     5.656739       no
#  Acutalibacter_sp009936055    7.121668       no
#  Acutalibacter_muris          5.648160       no
#  Kineothrix_sp000403275       2.359975      yes
#  14-2_sp000403315             3.583498      yes
#
#  [67 rows x 12 columns]}

# %%
# check if there are more than 20 features --> if so, only display top and bottom 10 
# otherwise display all 

def display_top_n_feats(df, n, yvar, xvar, xlab, ylab, title):
    if df.shape[0] < 2*n: 
        df_for_display = df 
    else: 
        bottomn = df[:n]
        topn = df[-1*n:]
        df_for_display = pd.concat([bottomn, topn])
    
    sns.stripplot(data=df_for_display, y=yvar, x=xvar)
    plt.errorbar(data=df_for_display, 
                 x=xvar, y=yvar,
                 xerr=df_for_display[['lower', 'upper']].T, ls='none')
    plt.ylabel(ylab)
    plt.xlabel(xlab)
    plt.title(title)
    plt.show()

# %%
for k in data_dict.keys(): 
    for v in vars_to_check.keys(): 
        if v in k:
            xlab = 'Ratio for ' + v
            var = vars_to_check[v]
            
    ylab = k.split('_')[1] + ' Feature'
    df_for_display = data_dict[k].reset_index()
    df_for_display = df_for_display.loc[df_for_display.credible == 'yes']
    fig, ax = plt.subplots(figsize=(6, 10))
    display_top_n_feats(df_for_display, 25, 'Feature', var+'mean', xlab, ylab,
                        'Top Features: ' + k)

# %% [markdown]
# # Targeted BSH

# %%
light=pd.read_csv('/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/targeted_BSH/inferences/inferences-results/genomeL_noNT_rmdbton.beta_var.tsv', sep='\t', index_col='Feature')
light
# Out:
#                                 Intercept_mean  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT               -9.112935
# tr_A0A852T2K3_A0A852T2K3_9MICO      -11.596079
# tr_A0A173URL3_A0A173URL3_9FIRM      -11.845634
# tr_A0A433NP38_A0A433NP38_CHLFR       -9.949231
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO      -10.152496
# ...                                        ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM      -11.982848
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN      -11.456474
# tr_A0A494SMF7_A0A494SMF7_ENTCA      -10.040423
# tr_A6L8X0_A6L8X0_PARD8              -12.368882
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM       -6.921100
#
#                                 C(condition, Treatment('FA'))[T.FT]_mean  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                                          1.043976
# tr_A0A852T2K3_A0A852T2K3_9MICO                                  1.444173
# tr_A0A173URL3_A0A173URL3_9FIRM                                 -2.462732
# tr_A0A433NP38_A0A433NP38_CHLFR                                 -4.029190
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                                 -3.829243
# ...                                                                  ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                                 -2.443043
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                                  2.258277
# tr_A0A494SMF7_A0A494SMF7_ENTCA                                 -4.063646
# tr_A6L8X0_A6L8X0_PARD8                                         -2.775797
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                  0.706632
#
#                                 C(condition, Treatment('FA'))[T.NA]_mean  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                                          0.952974
# tr_A0A852T2K3_A0A852T2K3_9MICO                                  2.838755
# tr_A0A173URL3_A0A173URL3_9FIRM                                  2.416087
# tr_A0A433NP38_A0A433NP38_CHLFR                                  3.155804
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                                 -0.257375
# ...                                                                  ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                                  2.873633
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                                  3.327125
# tr_A0A494SMF7_A0A494SMF7_ENTCA                                  0.629280
# tr_A6L8X0_A6L8X0_PARD8                                          4.115662
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 -0.577720
#
#                                 Intercept_std  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT               0.729874
# tr_A0A852T2K3_A0A852T2K3_9MICO       1.762696
# tr_A0A173URL3_A0A173URL3_9FIRM       2.686088
# tr_A0A433NP38_A0A433NP38_CHLFR       1.186456
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO       1.158469
# ...                                       ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM       2.292365
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN       1.787379
# tr_A0A494SMF7_A0A494SMF7_ENTCA       1.099563
# tr_A6L8X0_A6L8X0_PARD8               2.065163
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM       0.857217
#
#                                 C(condition, Treatment('FA'))[T.FT]_std  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                                         0.884481
# tr_A0A852T2K3_A0A852T2K3_9MICO                                 2.006940
# tr_A0A173URL3_A0A173URL3_9FIRM                                 4.005486
# tr_A0A433NP38_A0A433NP38_CHLFR                                 3.162677
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                                 3.277275
# ...                                                                 ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                                 3.571852
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                                 1.967049
# tr_A0A494SMF7_A0A494SMF7_ENTCA                                 3.375085
# tr_A6L8X0_A6L8X0_PARD8                                         3.692600
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 1.203101
#
#                                 C(condition, Treatment('FA'))[T.NA]_std  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                                         0.783477
# tr_A0A852T2K3_A0A852T2K3_9MICO                                 1.793467
# tr_A0A173URL3_A0A173URL3_9FIRM                                 2.505439
# tr_A0A433NP38_A0A433NP38_CHLFR                                 1.225145
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                                 1.415025
# ...                                                                 ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                                 2.346958
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                                 1.815244
# tr_A0A494SMF7_A0A494SMF7_ENTCA                                 1.215434
# tr_A6L8X0_A6L8X0_PARD8                                         2.065965
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 1.087626
#
#                                        Intercept_hdi  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT          (-10.4994, -7.83306)
# tr_A0A852T2K3_A0A852T2K3_9MICO  (-14.7354, -8.71203)
# tr_A0A173URL3_A0A173URL3_9FIRM  (-17.3665, -7.55388)
# tr_A0A433NP38_A0A433NP38_CHLFR  (-12.1756, -7.78217)
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO  (-12.2299, -8.07903)
# ...                                              ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM  (-16.6393, -7.91337)
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN  (-14.7383, -8.45023)
# tr_A0A494SMF7_A0A494SMF7_ENTCA   (-12.0453, -8.1114)
# tr_A6L8X0_A6L8X0_PARD8          (-16.1128, -8.92994)
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM  (-8.32732, -5.22521)
#
#                                C(condition, Treatment('FA'))[T.FT]_hdi  \
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                            (-0.632105, 2.62792)
# tr_A0A852T2K3_A0A852T2K3_9MICO                     (-2.14216, 5.29222)
# tr_A0A173URL3_A0A173URL3_9FIRM                     (-10.8787, 4.25066)
# tr_A0A433NP38_A0A433NP38_CHLFR                     (-9.43964, 2.21854)
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                      (-10.1162, 1.6914)
# ...                                                                ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                     (-8.87582, 4.14718)
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                      (-1.29665, 5.9989)
# tr_A0A494SMF7_A0A494SMF7_ENTCA                    (-11.0711, 0.928815)
# tr_A6L8X0_A6L8X0_PARD8                              (-9.6577, 4.24244)
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                       (-1.3633, 3.0829)
#
#                                C(condition, Treatment('FA'))[T.NA]_hdi
# Feature
# tr_R5G8N9_R5G8N9_9CLOT                             (-0.439434, 2.4485)
# tr_A0A852T2K3_A0A852T2K3_9MICO                    (-0.236598, 6.14115)
# tr_A0A173URL3_A0A173URL3_9FIRM                     (-1.91969, 7.38616)
# tr_A0A433NP38_A0A433NP38_CHLFR                      (1.10907, 5.61754)
# tr_A0A1I3PH24_A0A1I3PH24_9FLAO                     (-2.83665, 2.60605)
# ...                                                                ...
# tr_A0A413YQ76_A0A413YQ76_9FIRM                      (-1.47599, 7.4702)
# tr_A0A1D2IZY6_A0A1D2IZY6_LISMN                     (0.241008, 6.64988)
# tr_A0A494SMF7_A0A494SMF7_ENTCA                     (-1.50084, 2.98202)
# tr_A6L8X0_A6L8X0_PARD8                             (0.672133, 7.88959)
# tr_A0A1U7NP31_A0A1U7NP31_9FIRM                     (-2.49108, 1.54088)
#
# [1446 rows x 9 columns]

# %%
data_dict = {
    'BSH_light': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/targeted_BSH/inferences/inferences-results/genomeL_noNT_rmdbton.beta_var.tsv', 
    'BSH_dark': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/targeted_BSH/inferences/inferences-results/genomeD_noNT_rmdbton.beta_var.tsv', 
}

vars_to_check = {
    'BSH_light' : 'C(condition, Treatment(\'FA\'))[T.FT]_',
    'BSH_dark' : 'C(condition, Treatment(\'FA\'))[T.FT]_'
}

# %%
# update names 
for k in data_dict.keys():
    df = read_results(data_dict[k])
    for v in vars_to_check: 
        if v in k: 
            var = vars_to_check[v] 
    print(k)
    print('Unfiltered Shape:  ' + str(df.shape))
    sub_df = unpack_hdi_and_filter(df, var+'hdi')
    print('Filtered Shape: ' + str(sub_df.loc[sub_df['credible'] == 'yes'].shape))
    sub_df.rename_axis(index='Feature', inplace=True)
    
    data_dict[k] = sub_df.sort_values(by=var+'mean')
# Out:
# BSH_light
# Unfiltered Shape:  (1446, 9)
# Filtered Shape: (30, 12)
# BSH_dark
# Unfiltered Shape:  (986, 9)
# Filtered Shape: (80, 12)

# %%
data_dict
# Out:
# {'BSH_light':                                 Intercept_mean  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT       -6.979039
#  tr_R5AP11_R5AP11_9BACT               -7.249993
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO       -7.504491
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT       -8.427978
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT       -8.668254
#  ...                                        ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO      -11.741715
#  tr_A0A415E649_A0A415E649_9FIRM      -12.366370
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH      -11.879205
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS      -11.879205
#  tr_A0A517TYY3_A0A517TYY3_9BACT      -11.881957
#
#                                  C(condition, Treatment('FA'))[T.FT]_mean  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                                 -5.753479
#  tr_R5AP11_R5AP11_9BACT                                         -5.620179
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                                 -5.487357
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                                 -4.850605
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                                 -4.778494
#  ...                                                                  ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                                  3.430242
#  tr_A0A415E649_A0A415E649_9FIRM                                  3.729649
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                                  3.816682
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                                  3.816682
#  tr_A0A517TYY3_A0A517TYY3_9BACT                                  4.944891
#
#                                  C(condition, Treatment('FA'))[T.NA]_mean  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                                 -0.687245
#  tr_R5AP11_R5AP11_9BACT                                         -0.214797
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                                  0.953232
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                                 -0.046636
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                                  1.922062
#  ...                                                                  ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                                  0.376366
#  tr_A0A415E649_A0A415E649_9FIRM                                 -3.269913
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                                 -3.437796
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                                 -3.437796
#  tr_A0A517TYY3_A0A517TYY3_9BACT                                 -3.590497
#
#                                  Intercept_std  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT       0.578135
#  tr_R5AP11_R5AP11_9BACT               0.535216
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO       0.361842
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT       0.545495
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT       0.605890
#  ...                                       ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO       1.890707
#  tr_A0A415E649_A0A415E649_9FIRM       2.278919
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH       2.553471
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS       2.553471
#  tr_A0A517TYY3_A0A517TYY3_9BACT       2.190159
#
#                                  C(condition, Treatment('FA'))[T.FT]_std  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                                 2.734078
#  tr_R5AP11_R5AP11_9BACT                                         2.820628
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                                 2.676334
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                                 2.792460
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                                 3.007885
#  ...                                                                 ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                                 1.967251
#  tr_A0A415E649_A0A415E649_9FIRM                                 2.346408
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                                 2.421560
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                                 2.421560
#  tr_A0A517TYY3_A0A517TYY3_9BACT                                 2.217640
#
#                                  C(condition, Treatment('FA'))[T.NA]_std  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                                 0.800423
#  tr_R5AP11_R5AP11_9BACT                                         0.666275
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                                 0.393558
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                                 0.636710
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                                 0.641776
#  ...                                                                 ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                                 2.183297
#  tr_A0A415E649_A0A415E649_9FIRM                                 3.592567
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                                 3.698609
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                                 3.698609
#  tr_A0A517TYY3_A0A517TYY3_9BACT                                 3.581782
#
#                                         Intercept_hdi  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT  (-8.10264, -5.92301)
#  tr_R5AP11_R5AP11_9BACT          (-8.30475, -6.27069)
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO   (-8.2107, -6.84093)
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT  (-9.46683, -7.50141)
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT  (-9.86186, -7.61691)
#  ...                                              ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO   (-15.253, -8.50519)
#  tr_A0A415E649_A0A415E649_9FIRM  (-16.9715, -8.64246)
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH  (-17.3752, -7.79941)
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS  (-17.3752, -7.79941)
#  tr_A0A517TYY3_A0A517TYY3_9BACT   (-16.1489, -8.1999)
#
#                                 C(condition, Treatment('FA'))[T.FT]_hdi  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                    (-11.2261, -1.29233)
#  tr_R5AP11_R5AP11_9BACT                           (-10.9243, -0.914877)
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                     (-10.532, -1.28963)
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                   (-10.2799, -0.307616)
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                    (-10.3663, 0.175637)
#  ...                                                                ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                     (0.109574, 7.16932)
#  tr_A0A415E649_A0A415E649_9FIRM                     (-0.417201, 8.4592)
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                    (-0.420432, 8.55928)
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                    (-0.420432, 8.55928)
#  tr_A0A517TYY3_A0A517TYY3_9BACT                      (1.06713, 9.17268)
#
#                                 C(condition, Treatment('FA'))[T.NA]_hdi  \
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT                    (-2.25329, 0.712039)
#  tr_R5AP11_R5AP11_9BACT                             (-1.40072, 1.14191)
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO                     (0.180234, 1.67759)
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT                     (-1.17789, 1.16459)
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT                     (0.654187, 3.03625)
#  ...                                                                ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO                     (-3.57473, 4.69396)
#  tr_A0A415E649_A0A415E649_9FIRM                     (-9.98994, 3.31543)
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH                     (-10.5557, 3.40966)
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS                     (-10.5557, 3.40966)
#  tr_A0A517TYY3_A0A517TYY3_9BACT                     (-10.1012, 2.94187)
#
#                                     lower     upper credible
#  Feature
#  tr_A0A4P7W1A3_A0A4P7W1A3_9BACT  5.472621  4.461149      yes
#  tr_R5AP11_R5AP11_9BACT          5.304121  4.705302      yes
#  tr_A0A8I0Q0T5_A0A8I0Q0T5_MORMO  5.044643  4.197727      yes
#  tr_A0A6I1MM49_A0A6I1MM49_9CLOT  5.429295  4.542989      yes
#  tr_A0A0F5JLM1_A0A0F5JLM1_9BACT  5.587806  4.954131       no
#  ...                                  ...       ...      ...
#  tr_A0A224VHP0_A0A224VHP0_9LACO  3.320668  3.739078      yes
#  tr_A0A415E649_A0A415E649_9FIRM  4.146850  4.729551       no
#  tr_A0A1T4RBG9_A0A1T4RBG9_9HYPH  4.237114  4.742598       no
#  tr_A0A2I7N8C7_A0A2I7N8C7_9NEIS  4.237114  4.742598       no
#  tr_A0A517TYY3_A0A517TYY3_9BACT  3.877761  4.227789      yes
#
#  [1446 rows x 12 columns],
#  'BSH_dark':                                 Intercept_mean  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM       -6.513818
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM       -6.284820
#  tr_A0A437ST59_A0A437ST59_9LACO       -7.704121
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT       -7.519260
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4       -7.888201
#  ...                                        ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB      -11.765305
#  tr_A0A173S778_A0A173S778_9FIRM      -11.090890
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL      -11.223718
#  tr_A0A415G6B1_A0A415G6B1_9FIRM      -11.316302
#  tr_A0A415TWG6_A0A415TWG6_9FIRM      -11.134293
#
#                                  C(condition, Treatment('FA'))[T.FT]_mean  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                                 -6.158459
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 -5.852412
#  tr_A0A437ST59_A0A437ST59_9LACO                                 -5.515321
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                                 -5.372601
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                                 -5.343350
#  ...                                                                  ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                                  3.617230
#  tr_A0A173S778_A0A173S778_9FIRM                                  3.775352
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                                  3.783637
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                                  3.892737
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                                  3.903568
#
#                                  C(condition, Treatment('FA'))[T.NA]_mean  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                                 -1.391905
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                  0.638510
#  tr_A0A437ST59_A0A437ST59_9LACO                                 -1.009015
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                                 -0.167422
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                                 -6.108645
#  ...                                                                  ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                                  0.528679
#  tr_A0A173S778_A0A173S778_9FIRM                                  3.776405
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                                 -3.257575
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                                  4.018944
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                                  4.005704
#
#                                  Intercept_std  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM       0.600000
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM       1.057379
#  tr_A0A437ST59_A0A437ST59_9LACO       0.406788
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT       0.744962
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4       0.477697
#  ...                                       ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB       1.911328
#  tr_A0A173S778_A0A173S778_9FIRM       1.513735
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL       2.862832
#  tr_A0A415G6B1_A0A415G6B1_9FIRM       1.567948
#  tr_A0A415TWG6_A0A415TWG6_9FIRM       1.500716
#
#                                  C(condition, Treatment('FA'))[T.FT]_std  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                                 2.725333
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 3.135482
#  tr_A0A437ST59_A0A437ST59_9LACO                                 2.747501
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                                 2.862091
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                                 2.802463
#  ...                                                                 ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                                 1.941246
#  tr_A0A173S778_A0A173S778_9FIRM                                 1.543323
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                                 2.799501
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                                 1.581224
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                                 1.530244
#
#                                  C(condition, Treatment('FA'))[T.NA]_std  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                                 0.829976
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                                 1.449535
#  tr_A0A437ST59_A0A437ST59_9LACO                                 0.560044
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                                 0.969640
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                                 2.636303
#  ...                                                                 ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                                 2.127000
#  tr_A0A173S778_A0A173S778_9FIRM                                 1.517918
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                                 3.847862
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                                 1.576370
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                                 1.504924
#
#                                         Intercept_hdi  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM  (-7.59353, -5.27624)
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM  (-8.02481, -4.23753)
#  tr_A0A437ST59_A0A437ST59_9LACO  (-8.47988, -6.99241)
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT   (-8.8599, -6.04532)
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4  (-8.74191, -6.92204)
#  ...                                              ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB  (-15.6981, -8.94298)
#  tr_A0A173S778_A0A173S778_9FIRM     (-13.9, -8.40646)
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL  (-16.8299, -5.62813)
#  tr_A0A415G6B1_A0A415G6B1_9FIRM  (-14.3921, -8.79901)
#  tr_A0A415TWG6_A0A415TWG6_9FIRM   (-13.7611, -8.5082)
#
#                                 C(condition, Treatment('FA'))[T.FT]_hdi  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                    (-11.1552, -1.68835)
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                   (-12.4952, -0.749918)
#  tr_A0A437ST59_A0A437ST59_9LACO                    (-10.7986, -1.25115)
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                   (-10.9947, -0.649099)
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                    (-10.7582, -0.97943)
#  ...                                                                ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                     (0.469304, 7.54342)
#  tr_A0A173S778_A0A173S778_9FIRM                      (1.16161, 6.71486)
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                     (-1.23218, 9.63924)
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                      (1.37272, 7.07108)
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                      (1.16796, 6.63623)
#
#                                 C(condition, Treatment('FA'))[T.NA]_hdi  \
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM                    (-2.91776, 0.199795)
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM                     (-2.05933, 3.40895)
#  tr_A0A437ST59_A0A437ST59_9LACO                   (-2.03001, 0.0156801)
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT                     (-2.12748, 1.50012)
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4                    (-11.1782, -1.65607)
#  ...                                                                ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB                     (-3.19233, 4.77298)
#  tr_A0A173S778_A0A173S778_9FIRM                      (1.16123, 6.69481)
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL                     (-10.8475, 3.92622)
#  tr_A0A415G6B1_A0A415G6B1_9FIRM                      (1.42246, 7.00804)
#  tr_A0A415TWG6_A0A415TWG6_9FIRM                       (1.42446, 6.6573)
#
#                                     lower     upper credible
#  Feature
#  tr_A0A1U7NKD7_A0A1U7NKD7_9FIRM  4.996741  4.470109      yes
#  tr_A0A1U7NP31_A0A1U7NP31_9FIRM  6.642788  5.102494      yes
#  tr_A0A437ST59_A0A437ST59_9LACO  5.283279  4.264171      yes
#  tr_A0A2V1IYI9_A0A2V1IYI9_9BACT  5.622099  4.723502      yes
#  tr_A0A7J5J9S5_A0A7J5J9S5_BACT4  5.414850  4.363920      yes
#  ...                                  ...       ...      ...
#  tr_A0A2T0S0I3_A0A2T0S0I3_9RHOB  3.147926  3.926190      yes
#  tr_A0A173S778_A0A173S778_9FIRM  2.613742  2.939508      yes
#  tr_A0A418VDZ9_A0A418VDZ9_RHOPL  5.015817  5.855603       no
#  tr_A0A415G6B1_A0A415G6B1_9FIRM  2.520017  3.178343      yes
#  tr_A0A415TWG6_A0A415TWG6_9FIRM  2.735608  2.732662      yes
#
#  [986 rows x 12 columns]}

# %%
# check if there are more than 20 features --> if so, only display top and bottom 10 
# otherwise display all 

def display_top_n_feats(df, n, yvar, xvar, xlab, ylab, title):
    if df.shape[0] < 2*n: 
        df_for_display = df 
    else: 
        bottomn = df[:n]
        topn = df[-1*n:]
        df_for_display = pd.concat([bottomn, topn])
    
    sns.stripplot(data=df_for_display, y=yvar, x=xvar)
    plt.errorbar(data=df_for_display, 
                 x=xvar, y=yvar,
                 xerr=df_for_display[['lower', 'upper']].T, ls='none')
    plt.ylabel(ylab)
    plt.xlabel(xlab)
    plt.title(title)
    plt.show()

# %%
for k in data_dict.keys(): 
    for v in vars_to_check.keys(): 
        if v in k:
            xlab = 'Ratio for ' + v
            var = vars_to_check[v]
            
    ylab = k.split('_')[1] + ' Feature'
    df_for_display = data_dict[k].reset_index()
    df_for_display = df_for_display.loc[df_for_display.credible == 'yes']
    fig, ax = plt.subplots(figsize=(6, 10))
    display_top_n_feats(df_for_display, 25, 'Feature', var+'mean', xlab, ylab,
                        'Top Features: ' + k)

# %% [markdown]
# ## NA vs FA

# %%
light=pd.read_csv('/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences_2/inferences-results-2/species_pfam_BSHonly_clean_rmzero_noNT_light.beta_var.tsv', sep='\t', index_col='Feature')
light
# Out:
#                               Intercept_mean  \
# Feature
# Microbacterium_sp001427525         -6.462937
# Acinetobacter_tandoii              -9.377612
# UBA8158_sp003449595                -6.793530
# Anaerotruncus_sp000403395          -5.940813
# Enterococcus_B_faecium             -9.961910
# ...                                      ...
# Paraferrimonas_sedimenticola       -6.651565
# Bacillus_glycinifermentans         -7.384033
# 1XD8-76_sp003611955                -6.103128
# 14-2_sp000403255                   -6.525881
# Lactobacillus_gasseri              -4.557327
#
#                               C(condition, Treatment('NA'))[T.FA]_mean  \
# Feature
# Microbacterium_sp001427525                                   -1.868837
# Acinetobacter_tandoii                                         3.781688
# UBA8158_sp003449595                                          -2.052251
# Anaerotruncus_sp000403395                                     1.265969
# Enterococcus_B_faecium                                       -2.182616
# ...                                                                ...
# Paraferrimonas_sedimenticola                                 -1.971280
# Bacillus_glycinifermentans                                   -2.491267
# 1XD8-76_sp003611955                                          -1.619548
# 14-2_sp000403255                                              2.341432
# Lactobacillus_gasseri                                        -2.388283
#
#                               C(condition, Treatment('NA'))[T.FT]_mean  \
# Feature
# Microbacterium_sp001427525                                   -1.717750
# Acinetobacter_tandoii                                        -1.501831
# UBA8158_sp003449595                                          -2.183712
# Anaerotruncus_sp000403395                                    -3.626414
# Enterococcus_B_faecium                                        5.569224
# ...                                                                ...
# Paraferrimonas_sedimenticola                                 -1.766394
# Bacillus_glycinifermentans                                   -2.259225
# 1XD8-76_sp003611955                                          -1.738982
# 14-2_sp000403255                                              1.142009
# Lactobacillus_gasseri                                        -2.358105
#
#                               Intercept_std  \
# Feature
# Microbacterium_sp001427525         2.822528
# Acinetobacter_tandoii              3.166968
# UBA8158_sp003449595                2.740067
# Anaerotruncus_sp000403395          0.921899
# Enterococcus_B_faecium             2.188830
# ...                                     ...
# Paraferrimonas_sedimenticola       2.836889
# Bacillus_glycinifermentans         2.426208
# 1XD8-76_sp003611955                2.958602
# 14-2_sp000403255                   0.458755
# Lactobacillus_gasseri              2.327290
#
#                               C(condition, Treatment('NA'))[T.FA]_std  \
# Feature
# Microbacterium_sp001427525                                   4.331150
# Acinetobacter_tandoii                                        2.820213
# UBA8158_sp003449595                                          4.138474
# Anaerotruncus_sp000403395                                    1.703968
# Enterococcus_B_faecium                                       3.804507
# ...                                                               ...
# Paraferrimonas_sedimenticola                                 4.124206
# Bacillus_glycinifermentans                                   4.147685
# 1XD8-76_sp003611955                                          4.302326
# 14-2_sp000403255                                             0.674627
# Lactobacillus_gasseri                                        4.451324
#
#                               C(condition, Treatment('NA'))[T.FT]_std  \
# Feature
# Microbacterium_sp001427525                                   4.412851
# Acinetobacter_tandoii                                        4.119474
# UBA8158_sp003449595                                          4.191513
# Anaerotruncus_sp000403395                                    3.257982
# Enterococcus_B_faecium                                       2.135269
# ...                                                               ...
# Paraferrimonas_sedimenticola                                 4.322108
# Bacillus_glycinifermentans                                   4.121726
# 1XD8-76_sp003611955                                          4.304306
# 14-2_sp000403255                                             0.981159
# Lactobacillus_gasseri                                        4.439964
#
#                                       Intercept_hdi  \
# Feature
# Microbacterium_sp001427525    (-10.8246, -0.681942)
# Acinetobacter_tandoii          (-15.2394, -2.84914)
# UBA8158_sp003449595           (-10.7132, -0.871744)
# Anaerotruncus_sp000403395      (-7.42537, -4.12888)
# Enterococcus_B_faecium         (-14.6584, -6.28927)
# ...                                             ...
# Paraferrimonas_sedimenticola  (-10.8237, -0.796256)
# Bacillus_glycinifermentans       (-11.3062, -2.722)
# 1XD8-76_sp003611955           (-10.6027, 0.0640757)
# 14-2_sp000403255               (-7.40719, -5.69609)
# Lactobacillus_gasseri           (-8.0726, 0.377987)
#
#                              C(condition, Treatment('NA'))[T.FA]_hdi  \
# Feature
# Microbacterium_sp001427525                        (-9.6783, 7.00854)
# Acinetobacter_tandoii                            (-2.43111, 8.78058)
# UBA8158_sp003449595                                (-10.642, 5.1419)
# Anaerotruncus_sp000403395                        (-2.03491, 4.50763)
# Enterococcus_B_faecium                           (-9.41668, 4.78636)
# ...                                                              ...
# Paraferrimonas_sedimenticola                      (-10.1564, 5.3314)
# Bacillus_glycinifermentans                       (-10.1886, 5.43224)
# 1XD8-76_sp003611955                              (-9.55091, 6.97324)
# 14-2_sp000403255                                 (0.888632, 3.48019)
# Lactobacillus_gasseri                            (-9.80453, 7.03908)
#
#                              C(condition, Treatment('NA'))[T.FT]_hdi
# Feature
# Microbacterium_sp001427525                         (-10.37, 6.45176)
# Acinetobacter_tandoii                             (-9.31363, 5.9448)
# UBA8158_sp003449595                              (-9.84547, 6.11037)
# Anaerotruncus_sp000403395                         (-9.71629, 1.9656)
# Enterococcus_B_faecium                            (2.01963, 10.0464)
# ...                                                              ...
# Paraferrimonas_sedimenticola                     (-10.7044, 5.64617)
# Bacillus_glycinifermentans                       (-9.92546, 5.78791)
# 1XD8-76_sp003611955                              (-9.76319, 6.88619)
# 14-2_sp000403255                                (-0.861248, 2.84966)
# Lactobacillus_gasseri                            (-10.7161, 6.58795)
#
# [67 rows x 9 columns]

# %%
data_dict = {
    'BSH_light': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences_2/inferences-results-2/species_pfam_BSHonly_clean_rmzero_noNT_light.beta_var.tsv', 
    'BSH_dark': '/projects/zl_trf_metat/trf_metaT_woltka_results/wol2_wrep_notnorm/BSH_results/inferences_2/inferences-results-2/species_pfam_BSHonly_clean_rmzero_noNT_dark.beta_var.tsv', 
}

vars_to_check = {
    'BSH_light' : 'C(condition, Treatment(\'NA\'))[T.FA]_',
    'BSH_dark' : 'C(condition, Treatment(\'NA\'))[T.FA]_'
}

# %%
# update names 
for k in data_dict.keys():
    df = read_results(data_dict[k])
    for v in vars_to_check: 
        if v in k: 
            var = vars_to_check[v] 
    print(k)
    print('Unfiltered Shape:  ' + str(df.shape))
    sub_df = unpack_hdi_and_filter(df, var+'hdi')
    print('Filtered Shape: ' + str(sub_df.loc[sub_df['credible'] == 'yes'].shape))
    sub_df.rename_axis(index='Feature', inplace=True)
    
    data_dict[k] = sub_df.sort_values(by=var+'mean')
# Out:
# BSH_light
# Unfiltered Shape:  (67, 9)
# Filtered Shape: (10, 12)
# BSH_dark
# Unfiltered Shape:  (67, 9)
# Filtered Shape: (11, 12)

# %%
data_dict
# Out:
# {'BSH_light':                              Intercept_mean  \
#  Feature
#  14-2_sp000403315                  -1.824763
#  Eubacterium_J_plexicaudatum       -2.250609
#  1XD42-69_sp003612565              -2.712285
#  CAG-95_sp009917455                -2.953096
#  UBA3282_sp003611805               -3.022634
#  ...                                     ...
#  Evtepia_gabavorous                -8.519577
#  Acinetobacter_tandoii             -9.377612
#  Paramuribaculum_intestinale       -5.887449
#  Kineothrix_sp000403275            -6.495101
#  CAG-317_sp011960265               -8.045985
#
#                               C(condition, Treatment('NA'))[T.FA]_mean  \
#  Feature
#  14-2_sp000403315                                            -6.898959
#  Eubacterium_J_plexicaudatum                                 -6.814957
#  1XD42-69_sp003612565                                        -6.635886
#  CAG-95_sp009917455                                          -6.472831
#  UBA3282_sp003611805                                         -5.878104
#  ...                                                               ...
#  Evtepia_gabavorous                                           3.629418
#  Acinetobacter_tandoii                                        3.781688
#  Paramuribaculum_intestinale                                  5.224655
#  Kineothrix_sp000403275                                       5.268204
#  CAG-317_sp011960265                                          6.011088
#
#                               C(condition, Treatment('NA'))[T.FT]_mean  \
#  Feature
#  14-2_sp000403315                                            -3.342324
#  Eubacterium_J_plexicaudatum                                 -6.571163
#  1XD42-69_sp003612565                                        -6.170004
#  CAG-95_sp009917455                                          -5.931744
#  UBA3282_sp003611805                                         -1.312618
#  ...                                                               ...
#  Evtepia_gabavorous                                          -1.530694
#  Acinetobacter_tandoii                                       -1.501831
#  Paramuribaculum_intestinale                                 -1.775422
#  Kineothrix_sp000403275                                      -1.614333
#  CAG-317_sp011960265                                          4.533427
#
#                               Intercept_std  \
#  Feature
#  14-2_sp000403315                  0.436867
#  Eubacterium_J_plexicaudatum       0.323488
#  1XD42-69_sp003612565              0.213946
#  CAG-95_sp009917455                0.331643
#  UBA3282_sp003611805               0.577838
#  ...                                    ...
#  Evtepia_gabavorous                3.594906
#  Acinetobacter_tandoii             3.166968
#  Paramuribaculum_intestinale       3.837353
#  Kineothrix_sp000403275            3.636611
#  CAG-317_sp011960265               2.220252
#
#                               C(condition, Treatment('NA'))[T.FA]_std  \
#  Feature
#  14-2_sp000403315                                            2.589771
#  Eubacterium_J_plexicaudatum                                 2.516186
#  1XD42-69_sp003612565                                        2.648930
#  CAG-95_sp009917455                                          2.819688
#  UBA3282_sp003611805                                         2.808716
#  ...                                                              ...
#  Evtepia_gabavorous                                          3.351681
#  Acinetobacter_tandoii                                       2.820213
#  Paramuribaculum_intestinale                                 3.725938
#  Kineothrix_sp000403275                                      3.404073
#  CAG-317_sp011960265                                         2.239929
#
#                               C(condition, Treatment('NA'))[T.FT]_std  \
#  Feature
#  14-2_sp000403315                                            1.111188
#  Eubacterium_J_plexicaudatum                                 2.572046
#  1XD42-69_sp003612565                                        2.548953
#  CAG-95_sp009917455                                          2.682241
#  UBA3282_sp003611805                                         1.145813
#  ...                                                              ...
#  Evtepia_gabavorous                                          4.267579
#  Acinetobacter_tandoii                                       4.119474
#  Paramuribaculum_intestinale                                 4.444972
#  Kineothrix_sp000403275                                      4.469107
#  CAG-317_sp011960265                                         2.402899
#
#                                      Intercept_hdi  \
#  Feature
#  14-2_sp000403315             (-2.72169, -1.07025)
#  Eubacterium_J_plexicaudatum  (-2.83114, -1.62015)
#  1XD42-69_sp003612565         (-3.10037, -2.27128)
#  CAG-95_sp009917455           (-3.57763, -2.31371)
#  UBA3282_sp003611805          (-4.03267, -1.93652)
#  ...                                           ...
#  Evtepia_gabavorous           (-15.1423, -1.32152)
#  Acinetobacter_tandoii        (-15.2394, -2.84914)
#  Paramuribaculum_intestinale   (-12.3995, 1.55206)
#  Kineothrix_sp000403275       (-12.5001, 0.903552)
#  CAG-317_sp011960265          (-12.1395, -3.82497)
#
#                              C(condition, Treatment('NA'))[T.FA]_hdi  \
#  Feature
#  14-2_sp000403315                               (-12.0709, -2.71154)
#  Eubacterium_J_plexicaudatum                    (-11.5216, -2.60234)
#  1XD42-69_sp003612565                           (-11.7541, -2.36436)
#  CAG-95_sp009917455                             (-11.7015, -2.00438)
#  UBA3282_sp003611805                            (-11.0905, -1.04215)
#  ...                                                             ...
#  Evtepia_gabavorous                               (-3.56345, 9.3452)
#  Acinetobacter_tandoii                           (-2.43111, 8.78058)
#  Paramuribaculum_intestinale                     (-2.04205, 12.0537)
#  Kineothrix_sp000403275                          (-1.14366, 11.7065)
#  CAG-317_sp011960265                               (1.80756, 10.388)
#
#                              C(condition, Treatment('NA'))[T.FT]_hdi     lower  \
#  Feature
#  14-2_sp000403315                               (-5.52263, -1.33512)  5.171941
#  Eubacterium_J_plexicaudatum                    (-11.4064, -2.33859)  4.706643
#  1XD42-69_sp003612565                           (-11.2147, -2.32272)  5.118214
#  CAG-95_sp009917455                             (-11.1984, -1.77764)  5.228669
#  UBA3282_sp003611805                            (-3.38929, 0.970324)  5.212396
#  ...                                                             ...       ...
#  Evtepia_gabavorous                              (-9.62177, 6.01267)  7.192868
#  Acinetobacter_tandoii                            (-9.31363, 5.9448)  6.212798
#  Paramuribaculum_intestinale                     (-9.99662, 6.77372)  7.266705
#  Kineothrix_sp000403275                          (-9.96644, 6.92336)  6.411864
#  CAG-317_sp011960265                            (-0.348682, 8.99478)  4.203528
#
#                                  upper credible
#  Feature
#  14-2_sp000403315             4.187419      yes
#  Eubacterium_J_plexicaudatum  4.212617      yes
#  1XD42-69_sp003612565         4.271526      yes
#  CAG-95_sp009917455           4.468451      yes
#  UBA3282_sp003611805          4.835954      yes
#  ...                               ...      ...
#  Evtepia_gabavorous           5.715782       no
#  Acinetobacter_tandoii        4.998892       no
#  Paramuribaculum_intestinale  6.829045       no
#  Kineothrix_sp000403275       6.438296       no
#  CAG-317_sp011960265          4.376912      yes
#
#  [67 rows x 12 columns],
#  'BSH_dark':                              Intercept_mean  \
#  Feature
#  14-2_sp000403315                  -1.635084
#  UBA3282_sp003611805               -2.176345
#  COE1_sp000403215                  -2.886505
#  Ventrimonas_sp003611875           -3.583243
#  Lawsonibacter_sp000492175         -4.196486
#  ...                                     ...
#  Lactobacillus_hominis             -5.675748
#  Limosilactobacillus_reuteri       -8.991317
#  CAG-317_sp011960265               -8.571890
#  Lactobacillus_gasseri             -9.731244
#  Paramuribaculum_intestinale       -8.409045
#
#                               C(condition, Treatment('NA'))[T.FA]_mean  \
#  Feature
#  14-2_sp000403315                                            -7.184402
#  UBA3282_sp003611805                                         -6.448898
#  COE1_sp000403215                                            -6.295990
#  Ventrimonas_sp003611875                                     -6.035386
#  Lawsonibacter_sp000492175                                   -5.492178
#  ...                                                               ...
#  Lactobacillus_hominis                                        2.432727
#  Limosilactobacillus_reuteri                                  4.794986
#  CAG-317_sp011960265                                          5.315959
#  Lactobacillus_gasseri                                        5.388642
#  Paramuribaculum_intestinale                                  6.502744
#
#                               C(condition, Treatment('NA'))[T.FT]_mean  \
#  Feature
#  14-2_sp000403315                                            -2.258682
#  UBA3282_sp003611805                                         -1.839962
#  COE1_sp000403215                                            -5.956442
#  Ventrimonas_sp003611875                                     -5.420343
#  Lawsonibacter_sp000492175                                   -5.022156
#  ...                                                               ...
#  Lactobacillus_hominis                                       -3.311516
#  Limosilactobacillus_reuteri                                 -1.818918
#  CAG-317_sp011960265                                          6.561971
#  Lactobacillus_gasseri                                       -1.986304
#  Paramuribaculum_intestinale                                 -1.877922
#
#                               Intercept_std  \
#  Feature
#  14-2_sp000403315                  0.410476
#  UBA3282_sp003611805               0.653587
#  COE1_sp000403215                  0.454277
#  Ventrimonas_sp003611875           0.372611
#  Lawsonibacter_sp000492175         0.324315
#  ...                                    ...
#  Lactobacillus_hominis             1.545241
#  Limosilactobacillus_reuteri       2.647274
#  CAG-317_sp011960265               1.648744
#  Lactobacillus_gasseri             1.933460
#  Paramuribaculum_intestinale       2.622540
#
#                               C(condition, Treatment('NA'))[T.FA]_std  \
#  Feature
#  14-2_sp000403315                                            2.438742
#  UBA3282_sp003611805                                         2.735317
#  COE1_sp000403215                                            2.712745
#  Ventrimonas_sp003611875                                     2.860713
#  Lawsonibacter_sp000492175                                   2.714517
#  ...                                                              ...
#  Lactobacillus_hominis                                       2.070094
#  Limosilactobacillus_reuteri                                 2.543201
#  CAG-317_sp011960265                                         1.800267
#  Lactobacillus_gasseri                                       1.931263
#  Paramuribaculum_intestinale                                 2.722956
#
#                               C(condition, Treatment('NA'))[T.FT]_std  \
#  Feature
#  14-2_sp000403315                                            0.888384
#  UBA3282_sp003611805                                         1.448855
#  COE1_sp000403215                                            2.747792
#  Ventrimonas_sp003611875                                     2.700249
#  Lawsonibacter_sp000492175                                   2.835291
#  ...                                                              ...
#  Lactobacillus_hominis                                       3.768948
#  Limosilactobacillus_reuteri                                 4.001722
#  CAG-317_sp011960265                                         1.812763
#  Lactobacillus_gasseri                                       3.947893
#  Paramuribaculum_intestinale                                 3.973910
#
#                                       Intercept_hdi  \
#  Feature
#  14-2_sp000403315             (-2.39198, -0.848063)
#  UBA3282_sp003611805           (-3.3401, -0.911092)
#  COE1_sp000403215              (-3.70064, -2.01127)
#  Ventrimonas_sp003611875       (-4.30231, -2.90348)
#  Lawsonibacter_sp000492175      (-4.82741, -3.6086)
#  ...                                            ...
#  Lactobacillus_hominis         (-8.44435, -2.81741)
#  Limosilactobacillus_reuteri    (-14.469, -4.18519)
#  CAG-317_sp011960265           (-11.7168, -5.53116)
#  Lactobacillus_gasseri         (-13.5916, -6.46576)
#  Paramuribaculum_intestinale   (-13.3392, -3.27701)
#
#                              C(condition, Treatment('NA'))[T.FA]_hdi  \
#  Feature
#  14-2_sp000403315                               (-12.1579, -3.38983)
#  UBA3282_sp003611805                            (-11.6234, -1.46187)
#  COE1_sp000403215                               (-11.3108, -1.72529)
#  Ventrimonas_sp003611875                        (-11.3039, -1.27524)
#  Lawsonibacter_sp000492175                       (-10.7091, -1.1669)
#  ...                                                             ...
#  Lactobacillus_hominis                           (-1.71071, 6.30129)
#  Limosilactobacillus_reuteri                     (0.144633, 9.88522)
#  CAG-317_sp011960265                              (1.85841, 8.80104)
#  Lactobacillus_gasseri                            (1.67423, 9.04394)
#  Paramuribaculum_intestinale                      (1.24989, 11.7866)
#
#                              C(condition, Treatment('NA'))[T.FT]_hdi     lower  \
#  Feature
#  14-2_sp000403315                              (-4.06148, -0.675963)  4.973498
#  UBA3282_sp003611805                            (-4.52303, 0.905658)  5.174502
#  COE1_sp000403215                               (-11.1657, -1.31383)  5.014810
#  Ventrimonas_sp003611875                       (-10.4197, -0.911134)  5.268514
#  Lawsonibacter_sp000492175                      (-10.485, -0.424766)  5.216922
#  ...                                                             ...       ...
#  Lactobacillus_hominis                            (-10.859, 2.99119)  4.143437
#  Limosilactobacillus_reuteri                     (-9.36478, 5.85855)  4.650353
#  CAG-317_sp011960265                              (3.04211, 9.89803)  3.457549
#  Lactobacillus_gasseri                            (-10.058, 4.54616)  3.714412
#  Paramuribaculum_intestinale                      (-9.3222, 5.31744)  5.252854
#
#                                  upper credible
#  Feature
#  14-2_sp000403315             3.794572      yes
#  UBA3282_sp003611805          4.987028      yes
#  COE1_sp000403215             4.570700      yes
#  Ventrimonas_sp003611875      4.760146      yes
#  Lawsonibacter_sp000492175    4.325278      yes
#  ...                               ...      ...
#  Lactobacillus_hominis        3.868563       no
#  Limosilactobacillus_reuteri  5.090234      yes
#  CAG-317_sp011960265          3.485081      yes
#  Lactobacillus_gasseri        3.655298      yes
#  Paramuribaculum_intestinale  5.283856      yes
#
#  [67 rows x 12 columns]}

# %%
# check if there are more than 20 features --> if so, only display top and bottom 10 
# otherwise display all 

def display_top_n_feats(df, n, yvar, xvar, xlab, ylab, title):
    if df.shape[0] < 2*n: 
        df_for_display = df 
    else: 
        bottomn = df[:n]
        topn = df[-1*n:]
        df_for_display = pd.concat([bottomn, topn])
    
    sns.stripplot(data=df_for_display, y=yvar, x=xvar)
    plt.errorbar(data=df_for_display, 
                 x=xvar, y=yvar,
                 xerr=df_for_display[['lower', 'upper']].T, ls='none')
    plt.ylabel(ylab)
    plt.xlabel(xlab)
    plt.title(title)
    plt.show()

# %%
for k in data_dict.keys(): 
    for v in vars_to_check.keys(): 
        if v in k:
            xlab = 'Ratio for ' + v
            var = vars_to_check[v]
            
    ylab = k.split('_')[1] + ' Feature'
    df_for_display = data_dict[k].reset_index()
    df_for_display = df_for_display.loc[df_for_display.credible == 'yes']
    fig, ax = plt.subplots(figsize=(6, 10))
    display_top_n_feats(df_for_display, 25, 'Feature', var+'mean', xlab, ylab,
                        'Top Features: ' + k)
